# %% [markdown]
# # Binary Tree Traversal
# Raj Prasad
# July 2019
#
# [html version](https://daddyprasad5.github.io/binary_tree.html) - with all the code hidden away for a quick read
#
# [jupyter notebook version](https://github.com/daddyprasad5/thinkful/blob/master/binary_tree.ipynb) - with all the code exposed in an interactive notebook

# %%
class Node:
    def __init__(self, val):
        self.left = None
        self.right = None
        self.val = val
    def __repr__(self):
        return "Node, value {}".format(self.val)

    def __str__(self):
        return "Node, value {}".format(self.val)
        
# Establish the initial root node and children
root = Node('A')
root.left = Node('B')
root.right = Node('C')

# Add the appropriate children for 'B' and 'C'
root.left.left = Node('D')
root.left.right = Node('E')
root.right.left = Node('F')
root.right.right = Node('G')

root.left.left.left = Node('H')
root.left.left.right = Node('I')
root.left.right.left = Node('J')
root.left.right.right = Node('K')

root.right.left.left = Node('L')
root.right.left.right = Node('M')
root.right.right.left = Node('N')
root.right.right.right = Node('O')


#breadth first traversal

from queue import SimpleQueue

def readBinaryTree(node, to_read=SimpleQueue(), nodes=[]):
    if node is None:
        if to_read.qsize() > 0:
            node = to_read.get()
        else:
            return nodes
    nodes.append(node)
    if node.left is not None:
        to_read.put(node.left)
    if node.right is not None:
        to_read.put(node.right)
    return readNode(None, to_read, nodes)

readBinaryTree(node=root)
# Out:
# node is none and to_read is NOT empty
# -----------------
# processing a node:  Node, value B
# done processing a node...
# nodes  [Node, value A, Node, value B]
# to read  3
# -----------------
# node is none and to_read is NOT empty
# -----------------
# processing a node:  Node, value C
# done processing a node...
# nodes  [Node, value A, Node, value B, Node, value C]
# to read  4
# -----------------
# node is none and to_read is NOT empty
# -----------------
# processing a node:  Node, value D
# done processing a node...
# nodes  [Node, value A, Node, value B, Node, value C, Node, value D]
# to read  5
# -----------------
# node is none and to_read is NOT empty
# -----------------
# processing a node:  Node, value E
# done processing a node...
# nodes  [Node, value A, Node, value B, Node, value C, Node, value D, Node, value E]
# to read  6
# -----------------
# node is none and to_read is NOT empty
# -----------------
# processing a node:  Node, value F
# ...

# %%
type(root)
# Out:
# __main__.Node
